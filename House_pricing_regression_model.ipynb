# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
plt.show()

# %%
# Read the CSV file
file_path = 'C:/Users/PALMPAY/BostonHousing.csv'  # Replace with your CSV file path
boston = pd.read_csv(file_path)

# Display the first few rows of the dataset
print(boston.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  Price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
dataset=pd.DataFrame(boston)   # Create the DataFrame
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  Price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   5.33   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  Price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
## Summarizing The Stats of the data
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284341
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       Price
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
## Check the missing Values
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         5
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %%
# Fill missing values in the 'RM' column with the median
dataset['RM'] = dataset['RM'].fillna(dataset['RM'].median())

# %%
# Verify no missing values remain
print(dataset.isnull().sum())
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %%
### EXploratory Data Analysis
## Correlation
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.218823  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311007 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391654  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091722  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.301609  0.731470
# RM      -0.218823  0.311007 -0.391654  0.091722 -0.301609  1.000000 -0.239854
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.239854  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.201815 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209753  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.291581  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.356146  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.127547 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.614631  0.602339
# Price   -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695668 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT     Price
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.201815 -0.209753 -0.291581 -0.356146  0.127547 -0.614631  0.695668
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# Price    0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
plt.scatter(dataset['CRIM'],dataset['Price'])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
plt.show()

# %%
plt.scatter(dataset['RM'],dataset['Price'])
plt.xlabel("RM")
plt.ylabel("Price")
plt.show()

# %%
import seaborn as sns
sns.regplot(x="RM",y="Price",data=dataset)
plt.show()

# %%
sns.regplot(x="LSTAT",y="Price",data=dataset)
plt.show()

# %%
sns.regplot(x="CHAS",y="Price",data=dataset)
plt.show()

# %%
sns.regplot(x="PTRATIO",y="Price",data=dataset)
# Out:
# <Axes: xlabel='PTRATIO', ylabel='Price'>

# %%
X=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: Price, Length: 506, dtype: float64

# %%
##Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=43)

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 185   0.06047   0.0   2.46     0  0.488  6.153  68.8  3.2797    3  193
# 36    0.09744   0.0   5.96     0  0.499  5.841  61.4  3.3779    5  279
# 468  15.57570   0.0  18.10     0  0.580  5.926  71.0  2.9084   24  666
# 238   0.08244  30.0   4.93     0  0.428  6.481  18.5  6.1899    6  300
# 261   0.53412  20.0   3.97     0  0.647  7.520  89.4  2.1398    5  264
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 277   0.06127  40.0   6.41     1  0.447  6.826  27.6  4.8628    4  254
# 305   0.05479  33.0   2.18     0  0.472  6.616  58.1  3.3700    7  222
# 255   0.03548  80.0   3.64     0  0.392  5.876  19.1  9.2203    1  315
# 320   0.16760   0.0   7.38     0  0.493  6.426  52.3  4.5404    5  287
# 324   0.34109   0.0   7.38     0  0.493  6.415  40.1  4.7211    5  287
#
#      PTRATIO       B  LSTAT
# 185     17.8  387.11  13.15
# 36      19.2  377.56  11.41
# 468     20.2  368.74  18.13
# 238     16.6  379.41   6.36
# 261     13.0  388.37   7.26
# ..       ...     ...    ...
# 277     17.6  393.45   4.16
# 305     18.4  393.36   8.93
# 255     16.4  395.18   9.25
# 320     19.6  396.90   7.20
# 324     19.6  396.90   6.12
#
# [354 rows x 13 columns]

# %%
X_test
# Out:
#         CRIM     ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 360  4.54192    0.0  18.10     0  0.770  6.398  88.0  2.5182   24  666
# 391  5.29305    0.0  18.10     0  0.700  6.051  82.5  2.1678   24  666
# 247  0.19657   22.0   5.86     0  0.431  6.226  79.2  8.0555    7  330
# 57   0.01432  100.0   1.32     0  0.411  6.816  40.5  8.3248    5  256
# 244  0.20608   22.0   5.86     0  0.431  5.593  76.5  7.9549    7  330
# ..       ...    ...    ...   ...    ...    ...   ...     ...  ...  ...
# 0    0.00632   18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 321  0.18159    0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 336  0.03427    0.0   5.19     0  0.515  5.869  46.3  5.2311    5  224
# 210  0.17446    0.0  10.59     1  0.489  5.960  92.1  3.8771    4  277
# 231  0.46296    0.0   6.20     0  0.504  7.412  76.9  3.6715    8  307
#
#      PTRATIO       B  LSTAT
# 360     20.2  374.56   7.79
# 391     20.2  378.38  18.76
# 247     19.1  376.14  10.15
# 57      15.1  392.90   3.95
# 244     19.1  372.49  12.50
# ..       ...     ...    ...
# 0       15.3  396.90   4.98
# 321     19.6  396.90   6.87
# 336     20.2  396.90   9.80
# 210     18.6  393.25  17.27
# 231     17.4  376.14   5.25
#
# [152 rows x 13 columns]

# %%
## Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
X_train
# Out:
# array([[-0.43691461, -0.50860957, -1.23989   , ..., -0.26093326,
#          0.3318561 ,  0.17188483],
#        [-0.43170095, -0.50860957, -0.7188324 , ...,  0.37422648,
#          0.22581654, -0.09455915],
#        [ 1.75110576, -0.50860957,  1.08849312, ...,  0.82791201,
#          0.12788263,  0.93446589],
#        ...,
#        [-0.4404388 ,  2.78821418, -1.06421915, ..., -0.896093  ,
#          0.4214623 , -0.4253172 ],
#        [-0.4218067 , -0.50860957, -0.50743188, ...,  0.55570069,
#          0.44056052, -0.73923109],
#        [-0.39734044, -0.50860957, -0.50743188, ...,  0.55570069,
#          0.44056052, -0.90461011]])

# %%
X_test
# Out:
# array([[ 0.19507756, -0.50860957,  1.08849312, ...,  0.82791201,
#          0.19250569, -0.64888514],
#        [ 0.30100495, -0.50860957,  1.08849312, ...,  0.82791201,
#          0.23492151,  1.03093698],
#        [-0.41772124,  0.39801696, -0.73371976, ...,  0.32885793,
#          0.21004941, -0.28750135],
#        ...,
#        [-0.44060944, -0.50860957, -0.83346507, ...,  0.82791201,
#          0.44056052, -0.3410964 ],
#        [-0.42083928, -0.50860957, -0.02954762, ...,  0.10201516,
#          0.40003231,  0.80277518],
#        [-0.38015384, -0.50860957, -0.68310273, ..., -0.44240747,
#          0.21004941, -1.0378321 ]])

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## print the coefficients and the intercept
print(regression.coef_)
# Out:
# [-0.22529519  1.05496715  0.26236725  0.63717608 -2.01606732  2.57654521
#   0.64341126 -2.54340264  3.01310165 -2.37729194 -2.21346028  1.01972991
#  -4.23278361]

# %%
print(regression.intercept_)
# Out:
# 22.96016949152543

# %%
## on which parameters the model has been trained
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
### Prediction With Test Data
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([23.51716728, 16.65096649, 20.97070304, 34.16010569, 17.07612196,
#        12.37019149, 13.30485546, 25.17649337, 22.54755624,  7.33722735,
#        27.9033463 , 26.70904655, 16.58358937, 20.91507374, 22.25400037,
#        12.0271311 , 31.82903836, 33.09103796, 14.53047418, 41.16823854,
#        20.73632984,  8.21934733, 21.0359357 , 31.7198185 ,  6.37817656,
#        25.47078022, 20.14965623, 19.76069942, 19.25365501,  6.56011739,
#        21.48800301, 23.53620045, 15.52687514,  8.86475669, 24.36305423,
#        18.85666797, 16.17204676, 20.58341896, 28.70366594, 26.60811164,
#        20.73273398,  5.29360093, 25.65902368, 17.89286254, 38.74683368,
#        18.2560065 , 24.14390272, 22.31706144, 35.49045575, 18.10258305,
#        27.99672071, 37.95285532, 35.07923136, 22.02936018, 11.68459193,
#        38.38100839, 33.84960566, 25.84756314, 28.81789204, 28.77855649,
#        22.65665394, 14.11301617, 25.9665752 , 27.80065811, 27.31777869,
#        13.00033801, 22.72567694, 36.67284792,  7.55801869, 24.49689282,
#        12.92804952,  2.39527157,  8.26849309, -1.01807603,  5.95513507,
#        27.32312044, 25.06933297, 19.71757597, 22.71129325, 20.31397937,
#        12.44128765, 19.73324226, 11.61794492,  7.02043655, 17.12899114,
#        30.32602381, 13.82661947, 37.18060193, 12.30767187, 10.78497672,
#        15.34505146, 19.11474675, 21.40380051, 30.18464153, 24.73370842,
#        19.95428974, 34.27047055, 29.57001441, 24.61428698, 34.90519475,
#        14.20304657, 21.45741782,  7.23205653, 26.33921938, 20.06108483,
#         0.66128682,  1.02321939, 20.01858574, 20.6716086 , 29.44743257,
#        -0.27258207, 30.44062874, 15.02647598, 11.44780259, 15.71089297,
#        18.29328288, 14.93492056, 18.83787058, 10.30904353, 17.91441449,
#        24.24140151, 22.71170657, 18.659526  ,  2.16829105, 20.9807374 ,
#        25.25065119, 29.4976042 , 31.7626831 , 12.03769765, 29.58885794,
#        30.47959744, 23.37318834, 22.88280129, 22.24430867, 18.72468803,
#        22.23507273, 21.14633146, 43.98432585, 20.43019106, 27.70037908,
#        17.64075644, 24.07501597, 14.6881882 , 15.98966766, 31.70546641,
#        27.16604868, 10.39588239, 30.43761346, 25.07118476, 20.06689501,
#        21.96431921, 34.0948313 ])

# %% [markdown]
# ## Assumptions

# %%
## plot a scatter plot for the prediction
plt.scatter(y_test,reg_pred)
plt.show()

# %%
## Residuals
residuals=y_test-reg_pred
plt.show()

# %%
residuals
# Out:
# 360    1.482833
# 391    6.549034
# 247   -0.470703
# 57    -2.560106
# 244    0.523878
#          ...
# 0     -6.437613
# 321   -1.971185
# 336   -0.566895
# 210   -0.264319
# 231   -2.394831
# Name: Price, Length: 152, dtype: float64

# %%
## Plot this residuals 
sns.displot(residuals,kind="kde")
plt.show()

# %%
## Scatter plot with respect to prediction and residuals
## uniform distribution
plt.scatter(reg_pred,residuals)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 3.5972353892726603
# 25.505648445017936
# 5.050311717608918

# %% [markdown]
# ## R square and adjusted R square
# Formula
#
# ## R^2 = 1 - SSR/SST
#
# R^2 = coefficient of determination SSR = sum of squares of residuals SST = total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.6901521461898461

# %% [markdown]
# ## Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)]
# where:
#
# R2: The R2 of the model n: The number of observations k: The number of predictor variables

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6609635802512084

# %%
print(X.shape)  # Should output (1, 13)
# Out:
# (506, 13)

# %% [markdown]
# ## New Data Prediction

# %%
X.iloc[0].to_numpy().reshape(1, -1)
# Out:
# [[6.320e-03 1.800e+01 2.310e+00 0.000e+00 5.380e-01 6.575e+00 6.520e+01
#   4.090e+00 1.000e+00 2.960e+02 1.530e+01 3.969e+02 4.980e+00]]

# %%
##transformation of new data
import warnings
warnings.filterwarnings("ignore")

scaler.transform(X.iloc[0].to_numpy().reshape(1,-1))
# Out:
# array([[-0.44455106,  0.23317578, -1.26222104, -0.26360274, -0.10375337,
#          0.37847471, -0.07580484,  0.11349018, -0.95895146, -0.65942992,
#         -1.39514708,  0.44056052, -1.07917686]])

# %%
regression.predict(scaler.transform(X.iloc[0].to_numpy().reshape(1,-1)))
# Out:
# array([30.43761346])

# %% [markdown]
# ## Pickling The Model file For Deployment

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
#Prediction
pickled_model.predict(scaler.transform(X.iloc[0].to_numpy().reshape(1,-1)))
# Out:
# array([30.43761346])
